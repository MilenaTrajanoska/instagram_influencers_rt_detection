# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('float_format', '{:f}'.format)

# %%
metadata = pd.read_csv('../data/influencers.txt', sep='\t', header=0)

# %%
metadata.dropna(axis=0, inplace=True)

# %%
metadata.describe()
# Out:
#            #Followers    #Followees        #Posts
# count    33935.000000  33935.000000  33935.000000
# mean    140329.874702   1531.588242   1487.183409
# std    1245163.055079   2274.896034   2187.174919
# min       1000.000000      0.000000    100.000000
# 25%       4951.500000    557.000000    538.000000
# 50%      16125.000000    974.000000    937.000000
# 75%      53565.500000   1828.000000   1732.000000
# max   96476007.000000 304758.000000 127520.000000

# %%
plt.figure(figsize=(15, 7))
sns.distplot(metadata['#Followers'])
plt.show()

# %%
plt.figure(figsize=(15, 7))
sns.distplot(metadata['#Followees'])
plt.show()

# %%
plt.figure(figsize=(15, 7))
sns.distplot(metadata['#Posts'])
plt.show()
